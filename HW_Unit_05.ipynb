# %% [markdown]
# ## Week 5 Assignment - DATASCI200 Introduction to Data Science Programming, UC Berkeley MIDS

# %% [markdown]
# Write code in this Jupyter Notebook to solve the following problems. Please upload this **Notebook** with your solutions to your GitHub repository and gradescope.
#
# Assignment due date: 11:59PM PT the night before the Week 6 Live Session.

# %% [markdown]
# ## Objectives:
#
# - Demonstrate how to define functions
# - Understand how to call functions from within other functions
# - Understand how to return results from a function
# - Use the Python namespace to configure variables
# - Use functions as objects to pass to other functions
# - Design and implement a recursive function
# - Demonstrate knowledge of the Try/Except error checking statements

# %% [markdown]
# ## General Guidelines:
#
# - All calculations need to be done in the functions (that includes any formatting)
# - Name your functions exactly as written in the problem statement
# - Please have your functions return the answer rather than printing it inside the function
# - Do not make a separate input() statement. The functions will be passed the input as shown in the examples
# - The examples given are samples of how we will test/grade your code. Please ensure your functions output the same information
# - Answer format is graded - please match the examples
# - Other than for Part 5, user / function inputs do not need to be validated or checked. (For example, if the problem states input an integer we will check it by inputting an integer)
# - Docstrings and comments in your code are strongly suggested but won't be graded
# - In each code block, do NOT delete the ### comment at the top of a cell (it's needed for the auto-grading!)
#   - You will get 80 points from the autograder for this assignment and 20 points will be hidden. That is, passing all of the visible tests will give you 80 points. Make sure you are meeting the requirements of the problem to get the other 20 points!
#   - Do NOT print or put other statements in the grading cells. The autograder will fail - if this happens please delete those statments and re-submit
#   - You may upload and run the autograder as many times as needed in your time window to get full points
#   - The assignment needs to be named HW_Unit_05.ipynb to be graded from the autograder
#   - The examples given are samples of how we will test/grade your code. Please ensure your code outputs the same information.
#     - In addition to the given example, the autograder will test other examples
#     - Each autograder test tells you what input it is using
#   - Once complete, the autograder will show each tests, if that test is passed or failed, and your total score
#   - The autograder fails for a couple of reasons:
#     - Your code crashes with that input (for example: `Test Failed: string index out of range`)
#     - Your code output does not match the 'correct' output (for example: `Test Failed: '1 2 3 2 1' != '1 4 6 4 1'`)

# %% [markdown]
# ### 5-1 Nested ("Wrapped") Functions (20 points)
# For this question, please write three functions as follows:
#
# - `sum_digits`: a function which takes an `int` and returns the sum of its (positive value) digits.
#
# - `diff_sum_digits`: a function that "wraps" `sum_digits` in that it calls `sum_digits` from within it. Use the `diff_sum_digits` function to compute the absolute value of the input number, minus the sum of digits of the input number.
#
# - `wraps_diff_sum_digits`: a function that "wraps" `diff_sum_digits`. If `diff_sum_digits` returns a result that has more than one digit replace the result with the `diff_sum_digits` of the result. Do this repeatedly until the result has just one digit, then display it.
#
# - Note: The nested functions (all three functions above) will always run through once - even if the inputted number is only one digit!
#
# To illustrate this with an example:
# - The input number is 20 as in: `wraps_diff_sum_digits(20)`
# - `wraps_diff_sum_digits` calls `diff_sum_digits(20)` which calls `sum_digits(20)`
# - `sum_digits` adds the numbers (2+0 = 2) returns a 2, `diff_sum_digits` subtracts (20-2 = 18) and returns this to `wraps_diff_sum_digits`
# - `wraps_diff_sum_digits` sees that the number 18 stills has 2 digits and calls `diff_sum_digits(18)` which calls `sum_digits(18)`
# - `sum_digits` add the numbers (1+8 = 9) returns a 9, `diff_sum_digits` subtracts (18-9 = 9) and returns this to `wraps_diff_sum_digits`
# - `wraps_diff_sum_digits` sees that the number 9 only has 1 digit - stops and returns the value 9.
#
# Below you'll find an example of what we mean when we say "wraps".

# %%
def example_base_func(x):
    "Returns the value of the input * -1"
    return -1 * x

def wraps_example_base_func(x):
    temp_val = example_base_func(x)
    if temp_val < 0:
        return "trivial example"
    
print(example_base_func(5))
print(wraps_example_base_func(5))
# Out:
# -5
# trivial example

# %%
# Q5-1 Grading Tag:

def sum_digits(number):
    import math
    number = abs(number)
    if number == 0:
        digit_sum = 0
    else:   
        oom = math.floor(math.log10(number))
        digit_sum = 0
        for i in range(oom,-1,-1):
            mag = 10**i
            digit_sum += math.floor(number/mag)
            number -= math.floor(number/mag)*mag
            #print(f'_____i={i}, mag={mag}, digit_sum={digit_sum}, number={number}')
    return digit_sum

def diff_sum_digits(number):
    return abs(number) - sum_digits(number)

def wraps_diff_sum_digits(number):
    result = diff_sum_digits(number)
    while result > 9:
        result = diff_sum_digits(result)
    return result

# %%
# Test examples:

print(sum_digits(0))

print(sum_digits(54321) == 15)
print(sum_digits(-54321) == 15)
print(diff_sum_digits(54321) == 54306)
print(wraps_diff_sum_digits(54321) == 9)
print(wraps_diff_sum_digits(0) == 0)
# Out:
# 0
# _____i=4, mag=10000, digit_sum=5, number=4321
# _____i=3, mag=1000, digit_sum=9, number=321
# _____i=2, mag=100, digit_sum=12, number=21
# _____i=1, mag=10, digit_sum=14, number=1
# _____i=0, mag=1, digit_sum=15, number=0
# True
# _____i=4, mag=10000, digit_sum=5, number=4321
# _____i=3, mag=1000, digit_sum=9, number=321
# _____i=2, mag=100, digit_sum=12, number=21
# _____i=1, mag=10, digit_sum=14, number=1
# _____i=0, mag=1, digit_sum=15, number=0
# True
# _____i=4, mag=10000, digit_sum=5, number=4321
# _____i=3, mag=1000, digit_sum=9, number=321
# _____i=2, mag=100, digit_sum=12, number=21
# _____i=1, mag=10, digit_sum=14, number=1
# _____i=0, mag=1, digit_sum=15, number=0
# True
# _____i=4, mag=10000, digit_sum=5, number=4321
# _____i=3, mag=1000, digit_sum=9, number=321
# _____i=2, mag=100, digit_sum=12, number=21
# _____i=1, mag=10, digit_sum=14, number=1
# _____i=0, mag=1, digit_sum=15, number=0
# _____i=4, mag=10000, digit_sum=5, number=4306
# _____i=3, mag=1000, digit_sum=9, number=306
# _____i=2, mag=100, digit_sum=12, number=6
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4288
# _____i=3, mag=1000, digit_sum=9, number=288
# _____i=2, mag=100, digit_sum=11, number=88
# _____i=1, mag=10, digit_sum=19, number=8
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=4261
# _____i=3, mag=1000, digit_sum=9, number=261
# _____i=2, mag=100, digit_sum=11, number=61
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4243
# _____i=3, mag=1000, digit_sum=9, number=243
# _____i=2, mag=100, digit_sum=11, number=43
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4225
# _____i=3, mag=1000, digit_sum=9, number=225
# _____i=2, mag=100, digit_sum=11, number=25
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4207
# _____i=3, mag=1000, digit_sum=9, number=207
# _____i=2, mag=100, digit_sum=11, number=7
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4189
# _____i=3, mag=1000, digit_sum=9, number=189
# _____i=2, mag=100, digit_sum=10, number=89
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=4162
# _____i=3, mag=1000, digit_sum=9, number=162
# _____i=2, mag=100, digit_sum=10, number=62
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4144
# _____i=3, mag=1000, digit_sum=9, number=144
# _____i=2, mag=100, digit_sum=10, number=44
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4126
# _____i=3, mag=1000, digit_sum=9, number=126
# _____i=2, mag=100, digit_sum=10, number=26
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4108
# _____i=3, mag=1000, digit_sum=9, number=108
# _____i=2, mag=100, digit_sum=10, number=8
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4090
# _____i=3, mag=1000, digit_sum=9, number=90
# _____i=2, mag=100, digit_sum=9, number=90
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4072
# _____i=3, mag=1000, digit_sum=9, number=72
# _____i=2, mag=100, digit_sum=9, number=72
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4054
# _____i=3, mag=1000, digit_sum=9, number=54
# _____i=2, mag=100, digit_sum=9, number=54
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4036
# _____i=3, mag=1000, digit_sum=9, number=36
# _____i=2, mag=100, digit_sum=9, number=36
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4018
# _____i=3, mag=1000, digit_sum=9, number=18
# _____i=2, mag=100, digit_sum=9, number=18
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=4000
# _____i=3, mag=1000, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=3991
# _____i=3, mag=1000, digit_sum=8, number=991
# _____i=2, mag=100, digit_sum=17, number=91
# _____i=1, mag=10, digit_sum=26, number=1
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3964
# _____i=3, mag=1000, digit_sum=8, number=964
# _____i=2, mag=100, digit_sum=17, number=64
# _____i=1, mag=10, digit_sum=23, number=4
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3937
# _____i=3, mag=1000, digit_sum=8, number=937
# _____i=2, mag=100, digit_sum=17, number=37
# _____i=1, mag=10, digit_sum=20, number=7
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3910
# _____i=3, mag=1000, digit_sum=8, number=910
# _____i=2, mag=100, digit_sum=17, number=10
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3892
# _____i=3, mag=1000, digit_sum=8, number=892
# _____i=2, mag=100, digit_sum=16, number=92
# _____i=1, mag=10, digit_sum=25, number=2
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3865
# _____i=3, mag=1000, digit_sum=8, number=865
# _____i=2, mag=100, digit_sum=16, number=65
# _____i=1, mag=10, digit_sum=22, number=5
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3838
# _____i=3, mag=1000, digit_sum=8, number=838
# _____i=2, mag=100, digit_sum=16, number=38
# _____i=1, mag=10, digit_sum=19, number=8
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3811
# _____i=3, mag=1000, digit_sum=8, number=811
# _____i=2, mag=100, digit_sum=16, number=11
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3793
# _____i=3, mag=1000, digit_sum=8, number=793
# _____i=2, mag=100, digit_sum=15, number=93
# _____i=1, mag=10, digit_sum=24, number=3
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3766
# _____i=3, mag=1000, digit_sum=8, number=766
# _____i=2, mag=100, digit_sum=15, number=66
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3739
# _____i=3, mag=1000, digit_sum=8, number=739
# _____i=2, mag=100, digit_sum=15, number=39
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3712
# _____i=3, mag=1000, digit_sum=8, number=712
# _____i=2, mag=100, digit_sum=15, number=12
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3694
# _____i=3, mag=1000, digit_sum=8, number=694
# _____i=2, mag=100, digit_sum=14, number=94
# _____i=1, mag=10, digit_sum=23, number=4
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3667
# _____i=3, mag=1000, digit_sum=8, number=667
# _____i=2, mag=100, digit_sum=14, number=67
# _____i=1, mag=10, digit_sum=20, number=7
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3640
# _____i=3, mag=1000, digit_sum=8, number=640
# _____i=2, mag=100, digit_sum=14, number=40
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3622
# _____i=3, mag=1000, digit_sum=8, number=622
# _____i=2, mag=100, digit_sum=14, number=22
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3604
# _____i=3, mag=1000, digit_sum=8, number=604
# _____i=2, mag=100, digit_sum=14, number=4
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3586
# _____i=3, mag=1000, digit_sum=8, number=586
# _____i=2, mag=100, digit_sum=13, number=86
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3559
# _____i=3, mag=1000, digit_sum=8, number=559
# _____i=2, mag=100, digit_sum=13, number=59
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3532
# _____i=3, mag=1000, digit_sum=8, number=532
# _____i=2, mag=100, digit_sum=13, number=32
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3514
# _____i=3, mag=1000, digit_sum=8, number=514
# _____i=2, mag=100, digit_sum=13, number=14
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3496
# _____i=3, mag=1000, digit_sum=8, number=496
# _____i=2, mag=100, digit_sum=12, number=96
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3469
# _____i=3, mag=1000, digit_sum=8, number=469
# _____i=2, mag=100, digit_sum=12, number=69
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3442
# _____i=3, mag=1000, digit_sum=8, number=442
# _____i=2, mag=100, digit_sum=12, number=42
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3424
# _____i=3, mag=1000, digit_sum=8, number=424
# _____i=2, mag=100, digit_sum=12, number=24
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3406
# _____i=3, mag=1000, digit_sum=8, number=406
# _____i=2, mag=100, digit_sum=12, number=6
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3388
# _____i=3, mag=1000, digit_sum=8, number=388
# _____i=2, mag=100, digit_sum=11, number=88
# _____i=1, mag=10, digit_sum=19, number=8
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3361
# _____i=3, mag=1000, digit_sum=8, number=361
# _____i=2, mag=100, digit_sum=11, number=61
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3343
# _____i=3, mag=1000, digit_sum=8, number=343
# _____i=2, mag=100, digit_sum=11, number=43
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3325
# _____i=3, mag=1000, digit_sum=8, number=325
# _____i=2, mag=100, digit_sum=11, number=25
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3307
# _____i=3, mag=1000, digit_sum=8, number=307
# _____i=2, mag=100, digit_sum=11, number=7
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3289
# _____i=3, mag=1000, digit_sum=8, number=289
# _____i=2, mag=100, digit_sum=10, number=89
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=3262
# _____i=3, mag=1000, digit_sum=8, number=262
# _____i=2, mag=100, digit_sum=10, number=62
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3244
# _____i=3, mag=1000, digit_sum=8, number=244
# _____i=2, mag=100, digit_sum=10, number=44
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3226
# _____i=3, mag=1000, digit_sum=8, number=226
# _____i=2, mag=100, digit_sum=10, number=26
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3208
# _____i=3, mag=1000, digit_sum=8, number=208
# _____i=2, mag=100, digit_sum=10, number=8
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3190
# _____i=3, mag=1000, digit_sum=8, number=190
# _____i=2, mag=100, digit_sum=9, number=90
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3172
# _____i=3, mag=1000, digit_sum=8, number=172
# _____i=2, mag=100, digit_sum=9, number=72
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3154
# _____i=3, mag=1000, digit_sum=8, number=154
# _____i=2, mag=100, digit_sum=9, number=54
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3136
# _____i=3, mag=1000, digit_sum=8, number=136
# _____i=2, mag=100, digit_sum=9, number=36
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3118
# _____i=3, mag=1000, digit_sum=8, number=118
# _____i=2, mag=100, digit_sum=9, number=18
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3100
# _____i=3, mag=1000, digit_sum=8, number=100
# _____i=2, mag=100, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=3091
# _____i=3, mag=1000, digit_sum=8, number=91
# _____i=2, mag=100, digit_sum=8, number=91
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3073
# _____i=3, mag=1000, digit_sum=8, number=73
# _____i=2, mag=100, digit_sum=8, number=73
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3055
# _____i=3, mag=1000, digit_sum=8, number=55
# _____i=2, mag=100, digit_sum=8, number=55
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3037
# _____i=3, mag=1000, digit_sum=8, number=37
# _____i=2, mag=100, digit_sum=8, number=37
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3019
# _____i=3, mag=1000, digit_sum=8, number=19
# _____i=2, mag=100, digit_sum=8, number=19
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=3001
# _____i=3, mag=1000, digit_sum=8, number=1
# _____i=2, mag=100, digit_sum=8, number=1
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=2992
# _____i=3, mag=1000, digit_sum=7, number=992
# _____i=2, mag=100, digit_sum=16, number=92
# _____i=1, mag=10, digit_sum=25, number=2
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2965
# _____i=3, mag=1000, digit_sum=7, number=965
# _____i=2, mag=100, digit_sum=16, number=65
# _____i=1, mag=10, digit_sum=22, number=5
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2938
# _____i=3, mag=1000, digit_sum=7, number=938
# _____i=2, mag=100, digit_sum=16, number=38
# _____i=1, mag=10, digit_sum=19, number=8
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2911
# _____i=3, mag=1000, digit_sum=7, number=911
# _____i=2, mag=100, digit_sum=16, number=11
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2893
# _____i=3, mag=1000, digit_sum=7, number=893
# _____i=2, mag=100, digit_sum=15, number=93
# _____i=1, mag=10, digit_sum=24, number=3
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2866
# _____i=3, mag=1000, digit_sum=7, number=866
# _____i=2, mag=100, digit_sum=15, number=66
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2839
# _____i=3, mag=1000, digit_sum=7, number=839
# _____i=2, mag=100, digit_sum=15, number=39
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2812
# _____i=3, mag=1000, digit_sum=7, number=812
# _____i=2, mag=100, digit_sum=15, number=12
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2794
# _____i=3, mag=1000, digit_sum=7, number=794
# _____i=2, mag=100, digit_sum=14, number=94
# _____i=1, mag=10, digit_sum=23, number=4
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2767
# _____i=3, mag=1000, digit_sum=7, number=767
# _____i=2, mag=100, digit_sum=14, number=67
# _____i=1, mag=10, digit_sum=20, number=7
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2740
# _____i=3, mag=1000, digit_sum=7, number=740
# _____i=2, mag=100, digit_sum=14, number=40
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2722
# _____i=3, mag=1000, digit_sum=7, number=722
# _____i=2, mag=100, digit_sum=14, number=22
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2704
# _____i=3, mag=1000, digit_sum=7, number=704
# _____i=2, mag=100, digit_sum=14, number=4
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2686
# _____i=3, mag=1000, digit_sum=7, number=686
# _____i=2, mag=100, digit_sum=13, number=86
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2659
# _____i=3, mag=1000, digit_sum=7, number=659
# _____i=2, mag=100, digit_sum=13, number=59
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2632
# _____i=3, mag=1000, digit_sum=7, number=632
# _____i=2, mag=100, digit_sum=13, number=32
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2614
# _____i=3, mag=1000, digit_sum=7, number=614
# _____i=2, mag=100, digit_sum=13, number=14
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2596
# _____i=3, mag=1000, digit_sum=7, number=596
# _____i=2, mag=100, digit_sum=12, number=96
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2569
# _____i=3, mag=1000, digit_sum=7, number=569
# _____i=2, mag=100, digit_sum=12, number=69
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2542
# _____i=3, mag=1000, digit_sum=7, number=542
# _____i=2, mag=100, digit_sum=12, number=42
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2524
# _____i=3, mag=1000, digit_sum=7, number=524
# _____i=2, mag=100, digit_sum=12, number=24
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2506
# _____i=3, mag=1000, digit_sum=7, number=506
# _____i=2, mag=100, digit_sum=12, number=6
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2488
# _____i=3, mag=1000, digit_sum=7, number=488
# _____i=2, mag=100, digit_sum=11, number=88
# _____i=1, mag=10, digit_sum=19, number=8
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2461
# _____i=3, mag=1000, digit_sum=7, number=461
# _____i=2, mag=100, digit_sum=11, number=61
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2443
# _____i=3, mag=1000, digit_sum=7, number=443
# _____i=2, mag=100, digit_sum=11, number=43
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2425
# _____i=3, mag=1000, digit_sum=7, number=425
# _____i=2, mag=100, digit_sum=11, number=25
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2407
# _____i=3, mag=1000, digit_sum=7, number=407
# _____i=2, mag=100, digit_sum=11, number=7
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2389
# _____i=3, mag=1000, digit_sum=7, number=389
# _____i=2, mag=100, digit_sum=10, number=89
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=2362
# _____i=3, mag=1000, digit_sum=7, number=362
# _____i=2, mag=100, digit_sum=10, number=62
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2344
# _____i=3, mag=1000, digit_sum=7, number=344
# _____i=2, mag=100, digit_sum=10, number=44
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2326
# _____i=3, mag=1000, digit_sum=7, number=326
# _____i=2, mag=100, digit_sum=10, number=26
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2308
# _____i=3, mag=1000, digit_sum=7, number=308
# _____i=2, mag=100, digit_sum=10, number=8
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2290
# _____i=3, mag=1000, digit_sum=7, number=290
# _____i=2, mag=100, digit_sum=9, number=90
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2272
# _____i=3, mag=1000, digit_sum=7, number=272
# _____i=2, mag=100, digit_sum=9, number=72
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2254
# _____i=3, mag=1000, digit_sum=7, number=254
# _____i=2, mag=100, digit_sum=9, number=54
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2236
# _____i=3, mag=1000, digit_sum=7, number=236
# _____i=2, mag=100, digit_sum=9, number=36
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2218
# _____i=3, mag=1000, digit_sum=7, number=218
# _____i=2, mag=100, digit_sum=9, number=18
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2200
# _____i=3, mag=1000, digit_sum=7, number=200
# _____i=2, mag=100, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=2191
# _____i=3, mag=1000, digit_sum=7, number=191
# _____i=2, mag=100, digit_sum=8, number=91
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2173
# _____i=3, mag=1000, digit_sum=7, number=173
# _____i=2, mag=100, digit_sum=8, number=73
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2155
# _____i=3, mag=1000, digit_sum=7, number=155
# _____i=2, mag=100, digit_sum=8, number=55
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2137
# _____i=3, mag=1000, digit_sum=7, number=137
# _____i=2, mag=100, digit_sum=8, number=37
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2119
# _____i=3, mag=1000, digit_sum=7, number=119
# _____i=2, mag=100, digit_sum=8, number=19
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2101
# _____i=3, mag=1000, digit_sum=7, number=101
# _____i=2, mag=100, digit_sum=8, number=1
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=2092
# _____i=3, mag=1000, digit_sum=7, number=92
# _____i=2, mag=100, digit_sum=7, number=92
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2074
# _____i=3, mag=1000, digit_sum=7, number=74
# _____i=2, mag=100, digit_sum=7, number=74
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2056
# _____i=3, mag=1000, digit_sum=7, number=56
# _____i=2, mag=100, digit_sum=7, number=56
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2038
# _____i=3, mag=1000, digit_sum=7, number=38
# _____i=2, mag=100, digit_sum=7, number=38
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=2020
# _____i=3, mag=1000, digit_sum=7, number=20
# _____i=2, mag=100, digit_sum=7, number=20
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=2011
# _____i=3, mag=1000, digit_sum=7, number=11
# _____i=2, mag=100, digit_sum=7, number=11
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=2002
# _____i=3, mag=1000, digit_sum=7, number=2
# _____i=2, mag=100, digit_sum=7, number=2
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=1993
# _____i=3, mag=1000, digit_sum=6, number=993
# _____i=2, mag=100, digit_sum=15, number=93
# _____i=1, mag=10, digit_sum=24, number=3
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1966
# _____i=3, mag=1000, digit_sum=6, number=966
# _____i=2, mag=100, digit_sum=15, number=66
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1939
# _____i=3, mag=1000, digit_sum=6, number=939
# _____i=2, mag=100, digit_sum=15, number=39
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1912
# _____i=3, mag=1000, digit_sum=6, number=912
# _____i=2, mag=100, digit_sum=15, number=12
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1894
# _____i=3, mag=1000, digit_sum=6, number=894
# _____i=2, mag=100, digit_sum=14, number=94
# _____i=1, mag=10, digit_sum=23, number=4
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1867
# _____i=3, mag=1000, digit_sum=6, number=867
# _____i=2, mag=100, digit_sum=14, number=67
# _____i=1, mag=10, digit_sum=20, number=7
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1840
# _____i=3, mag=1000, digit_sum=6, number=840
# _____i=2, mag=100, digit_sum=14, number=40
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1822
# _____i=3, mag=1000, digit_sum=6, number=822
# _____i=2, mag=100, digit_sum=14, number=22
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1804
# _____i=3, mag=1000, digit_sum=6, number=804
# _____i=2, mag=100, digit_sum=14, number=4
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1786
# _____i=3, mag=1000, digit_sum=6, number=786
# _____i=2, mag=100, digit_sum=13, number=86
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1759
# _____i=3, mag=1000, digit_sum=6, number=759
# _____i=2, mag=100, digit_sum=13, number=59
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1732
# _____i=3, mag=1000, digit_sum=6, number=732
# _____i=2, mag=100, digit_sum=13, number=32
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1714
# _____i=3, mag=1000, digit_sum=6, number=714
# _____i=2, mag=100, digit_sum=13, number=14
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1696
# _____i=3, mag=1000, digit_sum=6, number=696
# _____i=2, mag=100, digit_sum=12, number=96
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1669
# _____i=3, mag=1000, digit_sum=6, number=669
# _____i=2, mag=100, digit_sum=12, number=69
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1642
# _____i=3, mag=1000, digit_sum=6, number=642
# _____i=2, mag=100, digit_sum=12, number=42
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1624
# _____i=3, mag=1000, digit_sum=6, number=624
# _____i=2, mag=100, digit_sum=12, number=24
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1606
# _____i=3, mag=1000, digit_sum=6, number=606
# _____i=2, mag=100, digit_sum=12, number=6
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1588
# _____i=3, mag=1000, digit_sum=6, number=588
# _____i=2, mag=100, digit_sum=11, number=88
# _____i=1, mag=10, digit_sum=19, number=8
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1561
# _____i=3, mag=1000, digit_sum=6, number=561
# _____i=2, mag=100, digit_sum=11, number=61
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1543
# _____i=3, mag=1000, digit_sum=6, number=543
# _____i=2, mag=100, digit_sum=11, number=43
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1525
# _____i=3, mag=1000, digit_sum=6, number=525
# _____i=2, mag=100, digit_sum=11, number=25
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1507
# _____i=3, mag=1000, digit_sum=6, number=507
# _____i=2, mag=100, digit_sum=11, number=7
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1489
# _____i=3, mag=1000, digit_sum=6, number=489
# _____i=2, mag=100, digit_sum=10, number=89
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=1462
# _____i=3, mag=1000, digit_sum=6, number=462
# _____i=2, mag=100, digit_sum=10, number=62
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1444
# _____i=3, mag=1000, digit_sum=6, number=444
# _____i=2, mag=100, digit_sum=10, number=44
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1426
# _____i=3, mag=1000, digit_sum=6, number=426
# _____i=2, mag=100, digit_sum=10, number=26
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1408
# _____i=3, mag=1000, digit_sum=6, number=408
# _____i=2, mag=100, digit_sum=10, number=8
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1390
# _____i=3, mag=1000, digit_sum=6, number=390
# _____i=2, mag=100, digit_sum=9, number=90
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1372
# _____i=3, mag=1000, digit_sum=6, number=372
# _____i=2, mag=100, digit_sum=9, number=72
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1354
# _____i=3, mag=1000, digit_sum=6, number=354
# _____i=2, mag=100, digit_sum=9, number=54
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1336
# _____i=3, mag=1000, digit_sum=6, number=336
# _____i=2, mag=100, digit_sum=9, number=36
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1318
# _____i=3, mag=1000, digit_sum=6, number=318
# _____i=2, mag=100, digit_sum=9, number=18
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1300
# _____i=3, mag=1000, digit_sum=6, number=300
# _____i=2, mag=100, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=1291
# _____i=3, mag=1000, digit_sum=6, number=291
# _____i=2, mag=100, digit_sum=8, number=91
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1273
# _____i=3, mag=1000, digit_sum=6, number=273
# _____i=2, mag=100, digit_sum=8, number=73
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1255
# _____i=3, mag=1000, digit_sum=6, number=255
# _____i=2, mag=100, digit_sum=8, number=55
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1237
# _____i=3, mag=1000, digit_sum=6, number=237
# _____i=2, mag=100, digit_sum=8, number=37
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1219
# _____i=3, mag=1000, digit_sum=6, number=219
# _____i=2, mag=100, digit_sum=8, number=19
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1201
# _____i=3, mag=1000, digit_sum=6, number=201
# _____i=2, mag=100, digit_sum=8, number=1
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=1192
# _____i=3, mag=1000, digit_sum=6, number=192
# _____i=2, mag=100, digit_sum=7, number=92
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1174
# _____i=3, mag=1000, digit_sum=6, number=174
# _____i=2, mag=100, digit_sum=7, number=74
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1156
# _____i=3, mag=1000, digit_sum=6, number=156
# _____i=2, mag=100, digit_sum=7, number=56
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1138
# _____i=3, mag=1000, digit_sum=6, number=138
# _____i=2, mag=100, digit_sum=7, number=38
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1120
# _____i=3, mag=1000, digit_sum=6, number=120
# _____i=2, mag=100, digit_sum=7, number=20
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=1111
# _____i=3, mag=1000, digit_sum=6, number=111
# _____i=2, mag=100, digit_sum=7, number=11
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=1102
# _____i=3, mag=1000, digit_sum=6, number=102
# _____i=2, mag=100, digit_sum=7, number=2
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=1093
# _____i=3, mag=1000, digit_sum=6, number=93
# _____i=2, mag=100, digit_sum=6, number=93
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1075
# _____i=3, mag=1000, digit_sum=6, number=75
# _____i=2, mag=100, digit_sum=6, number=75
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1057
# _____i=3, mag=1000, digit_sum=6, number=57
# _____i=2, mag=100, digit_sum=6, number=57
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1039
# _____i=3, mag=1000, digit_sum=6, number=39
# _____i=2, mag=100, digit_sum=6, number=39
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=1021
# _____i=3, mag=1000, digit_sum=6, number=21
# _____i=2, mag=100, digit_sum=6, number=21
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=1012
# _____i=3, mag=1000, digit_sum=6, number=12
# _____i=2, mag=100, digit_sum=6, number=12
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=1003
# _____i=3, mag=1000, digit_sum=6, number=3
# _____i=2, mag=100, digit_sum=6, number=3
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=994
# _____i=3, mag=1000, digit_sum=5, number=994
# _____i=2, mag=100, digit_sum=14, number=94
# _____i=1, mag=10, digit_sum=23, number=4
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=967
# _____i=3, mag=1000, digit_sum=5, number=967
# _____i=2, mag=100, digit_sum=14, number=67
# _____i=1, mag=10, digit_sum=20, number=7
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=940
# _____i=3, mag=1000, digit_sum=5, number=940
# _____i=2, mag=100, digit_sum=14, number=40
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=922
# _____i=3, mag=1000, digit_sum=5, number=922
# _____i=2, mag=100, digit_sum=14, number=22
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=904
# _____i=3, mag=1000, digit_sum=5, number=904
# _____i=2, mag=100, digit_sum=14, number=4
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=886
# _____i=3, mag=1000, digit_sum=5, number=886
# _____i=2, mag=100, digit_sum=13, number=86
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=859
# _____i=3, mag=1000, digit_sum=5, number=859
# _____i=2, mag=100, digit_sum=13, number=59
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=832
# _____i=3, mag=1000, digit_sum=5, number=832
# _____i=2, mag=100, digit_sum=13, number=32
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=814
# _____i=3, mag=1000, digit_sum=5, number=814
# _____i=2, mag=100, digit_sum=13, number=14
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=796
# _____i=3, mag=1000, digit_sum=5, number=796
# _____i=2, mag=100, digit_sum=12, number=96
# _____i=1, mag=10, digit_sum=21, number=6
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=769
# _____i=3, mag=1000, digit_sum=5, number=769
# _____i=2, mag=100, digit_sum=12, number=69
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=742
# _____i=3, mag=1000, digit_sum=5, number=742
# _____i=2, mag=100, digit_sum=12, number=42
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=724
# _____i=3, mag=1000, digit_sum=5, number=724
# _____i=2, mag=100, digit_sum=12, number=24
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=706
# _____i=3, mag=1000, digit_sum=5, number=706
# _____i=2, mag=100, digit_sum=12, number=6
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=688
# _____i=3, mag=1000, digit_sum=5, number=688
# _____i=2, mag=100, digit_sum=11, number=88
# _____i=1, mag=10, digit_sum=19, number=8
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=661
# _____i=3, mag=1000, digit_sum=5, number=661
# _____i=2, mag=100, digit_sum=11, number=61
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=643
# _____i=3, mag=1000, digit_sum=5, number=643
# _____i=2, mag=100, digit_sum=11, number=43
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=625
# _____i=3, mag=1000, digit_sum=5, number=625
# _____i=2, mag=100, digit_sum=11, number=25
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=607
# _____i=3, mag=1000, digit_sum=5, number=607
# _____i=2, mag=100, digit_sum=11, number=7
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=589
# _____i=3, mag=1000, digit_sum=5, number=589
# _____i=2, mag=100, digit_sum=10, number=89
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=4, mag=10000, digit_sum=5, number=562
# _____i=3, mag=1000, digit_sum=5, number=562
# _____i=2, mag=100, digit_sum=10, number=62
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=544
# _____i=3, mag=1000, digit_sum=5, number=544
# _____i=2, mag=100, digit_sum=10, number=44
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=526
# _____i=3, mag=1000, digit_sum=5, number=526
# _____i=2, mag=100, digit_sum=10, number=26
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=508
# _____i=3, mag=1000, digit_sum=5, number=508
# _____i=2, mag=100, digit_sum=10, number=8
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=490
# _____i=3, mag=1000, digit_sum=5, number=490
# _____i=2, mag=100, digit_sum=9, number=90
# _____i=1, mag=10, digit_sum=18, number=0
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=472
# _____i=3, mag=1000, digit_sum=5, number=472
# _____i=2, mag=100, digit_sum=9, number=72
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=454
# _____i=3, mag=1000, digit_sum=5, number=454
# _____i=2, mag=100, digit_sum=9, number=54
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=436
# _____i=3, mag=1000, digit_sum=5, number=436
# _____i=2, mag=100, digit_sum=9, number=36
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=418
# _____i=3, mag=1000, digit_sum=5, number=418
# _____i=2, mag=100, digit_sum=9, number=18
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=400
# _____i=3, mag=1000, digit_sum=5, number=400
# _____i=2, mag=100, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=391
# _____i=3, mag=1000, digit_sum=5, number=391
# _____i=2, mag=100, digit_sum=8, number=91
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=373
# _____i=3, mag=1000, digit_sum=5, number=373
# _____i=2, mag=100, digit_sum=8, number=73
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=355
# _____i=3, mag=1000, digit_sum=5, number=355
# _____i=2, mag=100, digit_sum=8, number=55
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=337
# _____i=3, mag=1000, digit_sum=5, number=337
# _____i=2, mag=100, digit_sum=8, number=37
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=319
# _____i=3, mag=1000, digit_sum=5, number=319
# _____i=2, mag=100, digit_sum=8, number=19
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=301
# _____i=3, mag=1000, digit_sum=5, number=301
# _____i=2, mag=100, digit_sum=8, number=1
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=292
# _____i=3, mag=1000, digit_sum=5, number=292
# _____i=2, mag=100, digit_sum=7, number=92
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=274
# _____i=3, mag=1000, digit_sum=5, number=274
# _____i=2, mag=100, digit_sum=7, number=74
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=256
# _____i=3, mag=1000, digit_sum=5, number=256
# _____i=2, mag=100, digit_sum=7, number=56
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=238
# _____i=3, mag=1000, digit_sum=5, number=238
# _____i=2, mag=100, digit_sum=7, number=38
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=220
# _____i=3, mag=1000, digit_sum=5, number=220
# _____i=2, mag=100, digit_sum=7, number=20
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=211
# _____i=3, mag=1000, digit_sum=5, number=211
# _____i=2, mag=100, digit_sum=7, number=11
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=202
# _____i=3, mag=1000, digit_sum=5, number=202
# _____i=2, mag=100, digit_sum=7, number=2
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=193
# _____i=3, mag=1000, digit_sum=5, number=193
# _____i=2, mag=100, digit_sum=6, number=93
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=175
# _____i=3, mag=1000, digit_sum=5, number=175
# _____i=2, mag=100, digit_sum=6, number=75
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=157
# _____i=3, mag=1000, digit_sum=5, number=157
# _____i=2, mag=100, digit_sum=6, number=57
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=139
# _____i=3, mag=1000, digit_sum=5, number=139
# _____i=2, mag=100, digit_sum=6, number=39
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=121
# _____i=3, mag=1000, digit_sum=5, number=121
# _____i=2, mag=100, digit_sum=6, number=21
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=112
# _____i=3, mag=1000, digit_sum=5, number=112
# _____i=2, mag=100, digit_sum=6, number=12
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=103
# _____i=3, mag=1000, digit_sum=5, number=103
# _____i=2, mag=100, digit_sum=6, number=3
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=4, mag=10000, digit_sum=5, number=94
# _____i=3, mag=1000, digit_sum=5, number=94
# _____i=2, mag=100, digit_sum=5, number=94
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=4, mag=10000, digit_sum=5, number=76
# _____i=3, mag=1000, digit_sum=5, number=76
# ...
# _____i=3, mag=1000, digit_sum=1, number=440
# _____i=2, mag=100, digit_sum=5, number=40
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=431
# _____i=2, mag=100, digit_sum=5, number=31
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=422
# _____i=2, mag=100, digit_sum=5, number=22
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=413
# _____i=2, mag=100, digit_sum=5, number=13
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=404
# _____i=2, mag=100, digit_sum=5, number=4
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=395
# _____i=2, mag=100, digit_sum=4, number=95
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=3, mag=1000, digit_sum=1, number=377
# _____i=2, mag=100, digit_sum=4, number=77
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=3, mag=1000, digit_sum=1, number=359
# _____i=2, mag=100, digit_sum=4, number=59
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=3, mag=1000, digit_sum=1, number=341
# _____i=2, mag=100, digit_sum=4, number=41
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=332
# _____i=2, mag=100, digit_sum=4, number=32
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=323
# _____i=2, mag=100, digit_sum=4, number=23
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=314
# _____i=2, mag=100, digit_sum=4, number=14
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=305
# _____i=2, mag=100, digit_sum=4, number=5
# _____i=1, mag=10, digit_sum=4, number=5
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=296
# _____i=2, mag=100, digit_sum=3, number=96
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=3, mag=1000, digit_sum=1, number=278
# _____i=2, mag=100, digit_sum=3, number=78
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=3, mag=1000, digit_sum=1, number=260
# _____i=2, mag=100, digit_sum=3, number=60
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=251
# _____i=2, mag=100, digit_sum=3, number=51
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=242
# _____i=2, mag=100, digit_sum=3, number=42
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=233
# _____i=2, mag=100, digit_sum=3, number=33
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=224
# _____i=2, mag=100, digit_sum=3, number=24
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=215
# _____i=2, mag=100, digit_sum=3, number=15
# _____i=1, mag=10, digit_sum=4, number=5
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=206
# _____i=2, mag=100, digit_sum=3, number=6
# _____i=1, mag=10, digit_sum=3, number=6
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=197
# _____i=2, mag=100, digit_sum=2, number=97
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=3, mag=1000, digit_sum=1, number=179
# _____i=2, mag=100, digit_sum=2, number=79
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=3, mag=1000, digit_sum=1, number=161
# _____i=2, mag=100, digit_sum=2, number=61
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=152
# _____i=2, mag=100, digit_sum=2, number=52
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=143
# _____i=2, mag=100, digit_sum=2, number=43
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=134
# _____i=2, mag=100, digit_sum=2, number=34
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=125
# _____i=2, mag=100, digit_sum=2, number=25
# _____i=1, mag=10, digit_sum=4, number=5
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=116
# _____i=2, mag=100, digit_sum=2, number=16
# _____i=1, mag=10, digit_sum=3, number=6
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=107
# _____i=2, mag=100, digit_sum=2, number=7
# _____i=1, mag=10, digit_sum=2, number=7
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=98
# _____i=2, mag=100, digit_sum=1, number=98
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=3, mag=1000, digit_sum=1, number=80
# _____i=2, mag=100, digit_sum=1, number=80
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=71
# _____i=2, mag=100, digit_sum=1, number=71
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=62
# _____i=2, mag=100, digit_sum=1, number=62
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=53
# _____i=2, mag=100, digit_sum=1, number=53
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=44
# _____i=2, mag=100, digit_sum=1, number=44
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=35
# _____i=2, mag=100, digit_sum=1, number=35
# _____i=1, mag=10, digit_sum=4, number=5
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=26
# _____i=2, mag=100, digit_sum=1, number=26
# _____i=1, mag=10, digit_sum=3, number=6
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=17
# _____i=2, mag=100, digit_sum=1, number=17
# _____i=1, mag=10, digit_sum=2, number=7
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=3, mag=1000, digit_sum=1, number=8
# _____i=2, mag=100, digit_sum=1, number=8
# _____i=1, mag=10, digit_sum=1, number=8
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=9, number=99
# _____i=1, mag=10, digit_sum=18, number=9
# _____i=0, mag=1, digit_sum=27, number=0
# _____i=2, mag=100, digit_sum=9, number=72
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=9, number=54
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=9, number=36
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=9, number=18
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=8, number=91
# _____i=1, mag=10, digit_sum=17, number=1
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=8, number=73
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=8, number=55
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=8, number=37
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=8, number=19
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=8, number=1
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=7, number=92
# _____i=1, mag=10, digit_sum=16, number=2
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=7, number=74
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=7, number=56
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=7, number=38
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=7, number=20
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=7, number=11
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=7, number=2
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=6, number=93
# _____i=1, mag=10, digit_sum=15, number=3
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=6, number=75
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=6, number=57
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=6, number=39
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=6, number=21
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=6, number=12
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=6, number=3
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=5, number=94
# _____i=1, mag=10, digit_sum=14, number=4
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=5, number=76
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=5, number=58
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=5, number=40
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=5, number=31
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=5, number=22
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=5, number=13
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=5, number=4
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=4, number=95
# _____i=1, mag=10, digit_sum=13, number=5
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=4, number=77
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=4, number=59
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=4, number=41
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=4, number=32
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=4, number=23
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=4, number=14
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=4, number=5
# _____i=1, mag=10, digit_sum=4, number=5
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=3, number=96
# _____i=1, mag=10, digit_sum=12, number=6
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=3, number=78
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=3, number=60
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=3, number=51
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=3, number=42
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=3, number=33
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=3, number=24
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=3, number=15
# _____i=1, mag=10, digit_sum=4, number=5
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=3, number=6
# _____i=1, mag=10, digit_sum=3, number=6
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=2, number=97
# _____i=1, mag=10, digit_sum=11, number=7
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=2, number=79
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=2, number=61
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=2, number=52
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=2, number=43
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=2, number=34
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=2, number=25
# _____i=1, mag=10, digit_sum=4, number=5
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=2, number=16
# _____i=1, mag=10, digit_sum=3, number=6
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=2, number=7
# _____i=1, mag=10, digit_sum=2, number=7
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=1, number=98
# _____i=1, mag=10, digit_sum=10, number=8
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=2, mag=100, digit_sum=1, number=80
# _____i=1, mag=10, digit_sum=9, number=0
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=1, number=71
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=1, number=62
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=1, number=53
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=1, number=44
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=1, number=35
# _____i=1, mag=10, digit_sum=4, number=5
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=1, number=26
# _____i=1, mag=10, digit_sum=3, number=6
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=1, number=17
# _____i=1, mag=10, digit_sum=2, number=7
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=2, mag=100, digit_sum=1, number=8
# _____i=1, mag=10, digit_sum=1, number=8
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=9, number=9
# _____i=0, mag=1, digit_sum=18, number=0
# _____i=1, mag=10, digit_sum=8, number=1
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=7, number=2
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=6, number=3
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=5, number=4
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=4, number=5
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=3, number=6
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=2, number=7
# _____i=0, mag=1, digit_sum=9, number=0
# _____i=1, mag=10, digit_sum=1, number=8
# _____i=0, mag=1, digit_sum=9, number=0
# True
# True

# %% [markdown]
# ### 5-2. Pigs, Continued (20 points)
#
# Write a function `is_consonant` that takes a character and returns `True` if it is a consonant.
#
# Use your function to create a new function `to_piglatin` that takes a word, moves all starting consonants (all consonants before the first vowel) to the end of the word, then adds *ay* to the end and returns the result. You may expect that the input to the function will be just one word. (we know this isn't **true** pig latin - please do not change this basic algorithm). For a single word input the first letter is capitalized and the rest are lower case as shown in the example below.
#
# Examples:
# ```
# (format is: function call -> returns) - do not return this whole string just return the word after the arrow.
#
# to_piglatin('stay') ->  Aystay
# to_piglatin('Jared') -> Aredjay
# to_piglatin('and') -> Anday
# to_piglatin('CAR') -> Arcay
# ```

# %%
# Q5-2 Grading Tag:

def is_consonant(character):
    flag = False
    if character in 'bcdfghjklmnpqrstvwxyz' or character in 'BCDFGHJKLMNPQRSTVWXYZ':
        flag = True
    return flag


def to_piglatin(word):
    word = word.lower()
    idx = -1
    for c in word:
        #print(c)
        if is_consonant(c) == True:
            idx += 1
        else:
            break
    #print(idx)
    word_out = word[idx+1].capitalize() + word[idx+2:] + word[0:idx+1] + 'ay'
    return word_out
    #print(word_out)

# %%
# Test examples:

print(to_piglatin('stay') == 'Aystay')
print(to_piglatin('Jared') == 'Aredjay')
print(to_piglatin('and') == 'Anday')
print(to_piglatin('CAR') == 'Arcay')

# %% [markdown]
# ## 5-3. Functions as Objects (20 points)
#
# ### 5-3-1. A Flexible "Scoring" Function (5 points)
#
# The following code defines a list of names and also contains a header for the function `best`.  The `best` function takes two arguments: a generic scoring function, score, and a list of strings, names.  Fill in the function so that it applies a score function to each string in the names list and returns the name with the highest score. If there are ties in the list, your function should return the first item with the maximum score. The `best` function needs to be designed so that it can take any scoring function and return the name with the highest score.
#
# For this question, define a function called `len_score` that returns the length of a word.  Call the `best` function with the `len_score` function as a parameter.
#
# Example:
# ```
# names = ["Ben", "April", "Zaber", "Alexis", "McJagger", "J.J.", "Madonna"]
#
# best(len_score, names) -> 'McJagger'
# ```

# %%
# Q5-3-1 Grading Tag:

def best(score, names):
    # YOUR CODE FOR best HERE
    values = [score(name) for name in names]
    #print(values)
    best_value = names[values.index(max(values))]
    #print(best_value)
    return best_value

def len_score(word):
    return len(word)

# %%
names = ["Ben", "April", "Zaber", "Alexis", "McJagger", "J.J.", "Madonna"]

best(len_score, names) == 'McJagger'

# %% [markdown]
# ### 5-3-2. Using Our Flexible Function (5 points)
#
# **NOTE: Do not change your best function from the answer in 5-3-1 above! The best function should be able to take any scoring function and return the result.** (you also do not need to copy your best function from above - we will run the cell above and then this cell in succession)
#
# Define a function, `number_of_vowels`, that returns the number of vowels in a string.  Pass it to your `best` function to find the name in `names` with the most vowels.
#
# See how easy it is to change the score function for different functionalities!
#
# Example:
# ```
# names = ["Ben", "April", "Zaber", "Alexis", "McJagger", "J.J.", "Madonna"]
#
# best(number_of_vowels, names) -> 'Alexis'
#
# ```

# %%
# Q5-3-2 Grading Tag:

def number_of_vowels(word):
    n_vowels = 0
    for i in word:
        if i in 'aeiou' or i in 'AEIOU':
            n_vowels +=1
    return n_vowels

# %%
# You can use the sample output in this cell to sanity check your work.

names = ["Ben", "April", "Zaber", "Alexis", "McJagger", "J.J.", "Madonna"]

best(number_of_vowels, names) == 'Alexis'

# %% [markdown]
# ### 5-3-3 Using Our Flexible Function with a Lambda Function (10 points)
#
# **NOTE: Do not change your best function from the answer in 5-3-1 above! The best function should be able to take any scoring function and return the result.** (you also do not need to copy your best function from above - we will run the cells above and then this cell in succession)
#
# Now pass a `lambda` function into your `best` function to find the name in `names` with the highest number of A's (upper or lower case). This needs to be a lambda function and only be one line!
#
# Example (replace `<lambda_function>` with the correct ```lambda```):
# ```
# names = ["Ben", "April", "Zaber", "Alexis", "McJagger", "J.J.", "MadonnA"]
#
# print(best(<lambda_function>, names))
#
# MadonnA
# ```

# %%
# Q5-3-3 Grading Tag: (also do not delete the names variable below)
names = ["Ben", "April", "Zaber", "Alexis", "McJagger", "J.J.", "MadonnA"] 

print(best(lambda word: word.count('a')+word.count('A') , names))

# %% [markdown]
# ### 5-4 Recursion - Computing Fibonacci Numbers (20 points)
#
# You are probably familiar (from two homework ago!) with the famous Fibonacci sequence of numbers, which begins like this:
# ```
# 1, 1, 2, 3, 5, 8, 13, 21...
# ```
# We'll index from 0, so the 0th and 1st numbers are both 1.  The 2nd Fibonacci number is found by summing the 0th and 1st: 1 + 1 = 2.  The 3rd is found by summing the 1st and 2nd: 1 + 2 = 3.  After this point, each Fibonacci number is found by summing the previous two numbers.
#
# You are to write a recursive function to compute the nth Fibonacci number.  This means that your function will call itself and will **NOT** include explicit loops.
#
# Hint: Your function should include a line that looks a lot like the mathematical definition of the nth Fibonacci number.
#
# Another Hint: It's possible for a recursive function to call itself more than once.
#
# Example:
# ```
# print(Fibonacci(1))
#
# 1
# ```

# %%
# Q5-4 Grading Tag:

def Fibonacci(n):
    if n == 0:
        return 1
    elif n == 1:
        return 1
    else:
        return Fibonacci(n-1) + Fibonacci(n-2)

# %%
# Test examples:

print(Fibonacci(1) == 1)
print(Fibonacci(2) == 2)
print(Fibonacci(3) == 3)

# %% [markdown]
# ### 5-5 Raising Custom Exceptions (20 points)
#
# Write a function called `weighted_avg` that takes a list of grades and a corresponding list of weights and returns the weighted average of the grades rounded to 1 decimal place.
#
# Your function should **raise an exception** with the message exactly as shown:
# - a weight is less than 0 or greater than 100 (message: "A weight is less than 0 or greater than 100")
# - the weights do not add to 100 (message: "Weights do not add to 100")
# - the number of weights and grades are not equal (message: "The number of weight and grades are not equal")
# - a grade is below 0 (grades above 100 would be considered extra credit and are acceptable)
#   (message: "A grade is below 0")
#
# Do not print the exception just 'raise' it.
#
# Run your function on `grades1` with `weights1` and `grades2` with `weights2` and `grades3` with `weights3` and `grades4` with `weights4`, defined below. Catch the errors generated in each case as an exception with the useful message for the user as defined above.
#
# Hint: The first 3 test cases should raise an exception!
#
# Example:
#
# ```
# weighted_avg(grades4, weights4)
#
# 85.0
# ```

# %%
# Q5-5 Grading Tag:

def weighted_avg(grades,weights):
    from decimal import Decimal
    #print(grades)
    #print(weights)
    if sum(weights) != 100:
        raise Exception('Weights do not add to 100')
    if len(grades) != len(weights):
        raise Exception('The number of weight and grades are not equal')
    total = 0
    for grade,weight in zip(grades,weights):
        if weight<0 or weight>100:
            raise Exception('A weight is less than 0 or greater than 100')
        if grade<0:
            raise Exception('A grade is below 0')
        total += grade*weight/100
    rounded_total = round(total,1)
    print(type(rounded_total))
    #print(rounded_total)
    return rounded_total

# %%
# Example grade/weights to try:

grades1 = [88,99,100,70]
weights1 = [30, 30, 30, 5]

grades2 = [78, 75, 80, 99]
weights2 = [110, 10, -20, 0]

grades3 = [84, 80, 67, 97]
weights3 = [50, 25, 25]

grades4 = [100, 80, 90, 75]
weights4 = [20, 25, 25, 30]

weighted_avg(grades4,weights4)
# Out:
# <class 'float'>
# 85.0

# %% [markdown]
# ## If you have feedback for this homework, please submit it using the link below:
#
# http://goo.gl/forms/74yCiQTf6k
